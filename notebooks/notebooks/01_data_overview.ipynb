# %% [markdown]
# # Data overview
# Load the processed open/literature crack-growth dataset.

# %%
import pandas as pd
df = pd.read_csv("../data/processed/literature_open_crack_growth_dataset.csv")
df.head()

# %%
df.groupby(["data_type", "alloy"]).size()
