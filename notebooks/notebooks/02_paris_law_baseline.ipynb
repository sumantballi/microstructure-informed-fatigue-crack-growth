# %% [markdown]
# # Paris-law baseline
# Fit a Paris-law baseline to measured FV566 data.

# %%
import sys
sys.path.append("..")
from src.data import load_dataset
from src.fracture_models import fit_paris_law
df = load_dataset()
sub = df[(df.alloy=="FV566 stainless steel") & (df.data_type=="measured")]
C, m, _ = fit_paris_law(sub.delta_k_mpa_sqrt_m, sub.dadn_mm_per_cycle)
C, m
